# %% [markdown]
# <a href="https://colab.research.google.com/github/aleenaann007/python-basics/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-f26cf7da-0e95-4327-a589-65435d782f22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f26cf7da-0e95-4327-a589-65435d782f22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dataframe=pd.read_csv("diabetes.csv")

# %%
dataframe. head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x=dataframe.drop('Outcome',1)
y=dataframe. Outcome
print(x)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
print(y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn. tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree=tree.fit(x_train,y_train)
predictedly= tree.predict(x_test)

# %%
from sklearn import metrics
accuracy=metrics.accuracy_score(y_test, predictedly)

# %%
from sklearn .tree import export_graphviz
from io import StringIO

# %%
dotdata=StringIO()
export_graphviz(tree,out_file=dotdata,filled=True,rounded=True,special_characters=True,class_names=['0','1'])
print(dotdata.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label=<X<SUB>1</SUB> &le; 144.5<br/>gini = 0.462<br/>samples = 537<br/>value = [343, 194]<br/>class = 0>, fillcolor="#f4c8a9"] ;
# 1 [label=<X<SUB>7</SUB> &le; 28.5<br/>gini = 0.368<br/>samples = 412<br/>value = [312, 100]<br/>class = 0>, fillcolor="#eda978"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<X<SUB>5</SUB> &le; 30.45<br/>gini = 0.203<br/>samples = 218<br/>value = [193, 25]<br/>class = 0>, fillcolor="#e89153"] ;
# 1 -> 2 ;
# 3 [label=<X<SUB>0</SUB> &le; 7.0<br/>gini = 0.037<br/>samples = 106<br/>value = [104, 2]<br/>class = 0>, fillcolor="#e6833d"] ;
# 2 -> 3 ;
# 4 [label=<X<SUB>6</SUB> &le; 0.672<br/>gini = 0.019<br/>samples = 105<br/>value = [104, 1]<br/>class = 0>, fillcolor="#e5823b"] ;
# 3 -> 4 ;
# 5 [label=<gini = 0.0<br/>samples = 92<br/>value = [92, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# ...

# %%
import pydotplus
graph=pydotplus.graph_from_dot_data(dotdata.getvalue())
graph.write_png("tree_for_diabetes.png")
# Out:
# True

# %%
from IPython.display import Image
Image(graph.create_png())
